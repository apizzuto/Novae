# %%
# %matplotlib inline

# %%
import sys
sys.path.append('/home/apizzuto/Nova/scripts/')
import plotting
#from plotting import GammaRayNova, GammaCatalog
from celluloid import Camera
import matplotlib.pyplot as plt
import matplotlib.animation as ani
from importlib import reload

# %%
reload(plotting)
# Out:
# <module 'plotting' from '/home/apizzuto/Nova/scripts/plotting.py'>

# %%
syn_plots = plotting.SynthesisPlots(save=False)

# %%
syn_plots.mollview_with_sensitivity()

# %%
cat = plotting.GammaCatalog(verbose = True, save=True)

# %%
cat.background_ts_panel()
plt.show()

# %%
for delta_t in cat.delta_ts[:]:
    cat.background_ts_panel(delta_t = delta_t)

# %%
cat.compare_photon_to_nus()

# %%
for gamma in [2., 2.5, 3.]:
    for disc in [True, False]:
        cat.sensitivity_vs_time(discovery=disc, annotate=False, gamma=gamma)

# %%
cat.

# %%
fig, ax = plt.subplots(dpi=150) #cat.compare_photon_to_nus(delta_t=1e1)
camera = Camera(fig)
for delta_t in cat.delta_ts:
    cat.compare_photon_to_nus(delta_t=delta_t, return_fig=False, fig=fig, ax=ax, omit_title=True)
    ax.text(2e1, 3e3, r"$\Delta T_{\nu} = $" + f"{delta_t:.2e} s")
    camera.snap()
    
fig.tight_layout()
animation = camera.animate(blit=False)
animation.save('/data/user/apizzuto/Nova/plots/animated_SED_versus_time.gif', 
               writer = 'imagemagick', fps=0.5)

# %%
# %matplotlib inline

fig, aaxs = plt.subplots(
                nrows=4, ncols=4, dpi=150,
                figsize=(14, 14), sharey=True, sharex=True)
plt.subplots_adjust(hspace=0.05, wspace=0.05)
camera = Camera(fig)
for gamma in [2.0, 2.5, 3.0]:
    cat.ns_fitting_panel(gamma=gamma, fig=fig, axs=aaxs, omit_title=True)
    camera.snap()
    
fig.tight_layout()
animation = camera.animate(blit=False)
animation.save('/data/user/apizzuto/Nova/plots/roung_trip_test_gammas.gif', 
               writer = 'imagemagick', fps=0.3)

# %%
cat.ns_fitting_panel(gamma=3.0, omit_title=True)

# %%
cat.full_time_novae['V5856 Sgr'].fitting_trials[2.0].ntrue
# Out:
# array([ 0,  0,  0, ..., 50, 50, 50])

# %%
for delta_t in cat.delta_ts:
    cat.ns_fitting_panel(delta_t=delta_t, gamma=2.0)

# %%
cat.gamma_fitting_panel()

# %%
nov = plotting.GammaRayNova('V959 Mon', verbose=True)
#a = nov.background_ts_plot()
nov.ns_fit_bias_plot(gamma=3.0)
nov.gamma_fit_bias_plot()
